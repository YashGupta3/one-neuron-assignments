# %%
for i in range(1,6):
    for j in range(i):
        print("*" ,end = " ")
    print("")
i=4
while i>0:
    for j in range(i):
        print("*", end = " ")
    i-=1
    print("")
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
word = input("Enter first name")
word = word[::-1]
print(word)
# Out:
# Enter first nameyash
# hsay
